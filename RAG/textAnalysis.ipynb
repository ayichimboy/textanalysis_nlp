# %%
# Import Libraries

import pandas as pd    
import numpy as np          
import re
import seaborn as sns                   
import matplotlib.pyplot as plt                 
from sklearn.preprocessing import StandardScaler

# %%
isfull = list(range(10))
ismissing = [ 9,5,4,3,2,1,0]

intersection = list(set(isfull) - set(ismissing))

print(intersection)
# Out:
# [8, 6, 7]

# %% [markdown]
# Text Analysis
